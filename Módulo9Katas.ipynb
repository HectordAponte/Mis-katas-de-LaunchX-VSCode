# %% [markdown]
# # Misión: Onboarding - Python
# ## Módulo 9: Funciones
# ### Tripulante: Héctor D. Aponte
#
# # Ejercicio: Uso de funciones en Python

# %% [markdown]
# ### Ejercicio 1: Trabajar con argumentos en funciones
#
# Los argumentos requeridos en las funciones se utilizan cuando las funciones necesitan que esos argumentos funcionen correctamente. En este ejercicio, construirás un informe de combustible que requiere información de varias ubicaciones de combustible en todo el cohete.

# %% [markdown]
# > **TIP**
# > Dedica unos minutos para tratar de encontrar una solución. Luego desplázate hacia abajo hasta la parte inferior para ver si has logrado compilar el programa de acuerdo con las especificaciones
#
# Comienza por crear una función que necesite tres lecturas de combustible y devuelva un informe:

# %%
# Función para leer 3 tanques de combustible y muestre el promedio

def tank_report(reading1, reading2, reading3):
    average = (reading1 + reading2 + reading3) / 3
    return f"""INFORME DE COMBUSTIBLE:
    {15 * '-'}
    Tanque 1: {reading1}%
    Tanque 2: {reading2}%
    Tanque 3: {reading3}%
    {30 * '-'}
    Promedio de los tanques: {average}%
    """

# %% [markdown]
# Ahora que hemos definido la función de informes, vamos a comprobarlo. Para esta misión, los tanques no están llenos:

# %%
# Llamamos a la función que genera el reporte print(funcion(tanque1, tanque2, tanque3))
print(tank_report(39, 45, 60))
# Out:
# INFORME DE COMBUSTIBLE:
#     ---------------
#     Tanque 1: 39%
#     Tanque 2: 45%
#     Tanque 3: 60%
#     ------------------------------
#     Promedio de los tanques: 48.0%

# %% [markdown]
# En lugar de simplemente crear el informe, la función también está calculando el promedio. Mejora la legibilidad extrayendo el cálculo promedio de la función en una nueva función para que el promedio se pueda hacer de forma independiente:

# %%
# Función promedio 
import statistics
from statistics import mean

def average_function(reading1, reading2, reading3):
    # average = (reading1 + reading2 + reading3) / 3
    average = statistics.mean([reading1, reading2, reading3])
    return average

# %% [markdown]
# Ahora actualiza la función de informes para llamando a la nueva función del promedio:

# %%
# Actualiza la función
def tank_report(reading1, reading2, reading3):
    
    return f"""INFORME DE COMBUSTIBLE:
    {15 * '-'}
    Tanque 1: {reading1}%
    Tanque 2: {reading2}%
    Tanque 3: {reading3}%
    {30 * '-'}
    Promedio de los tanques: {average_function(reading1, reading2, reading3)}%
    """

print(tank_report(65, 55, 44))
# Out:
# INFORME DE COMBUSTIBLE:
#     ---------------
#     Tanque 1: 65%
#     Tanque 2: 55%
#     Tanque 3: 44%
#     ------------------------------
#     Promedio de los tanques: 54.666666666666664%

# %% [markdown]
# > Recuerda: Lo importante es intentarlo, puedes auxiliarte de internet, libros, etc. El objetivo de una kata es la comprobación de la comprensión de la lección y su aplicación inmediata a la resolución de problemas. Go for it!

# %% [markdown]
# ## Ejercicio 2: Trabajo con argumentos de palabra clave

# %% [markdown]
# ### Ejercicio : Trabajar con argumentos de palabras clave en funciones
# En este ejercicio, construirás un informe de cohete que requiere varias piezas de información, como el tiempo hasta el destino, el combustible a la izquierda y el nombre del destino. Comienza por crear una función que creará un informe preciso de la misión:

# %%
# Función con un informe preciso de la misión. Considera hora de prelanzamiento, tiempo de vuelo, destino, tanque externo y tanque interno

def mission_report(prelaunch_time, flight_time, destination, ext_tank, int_tank):
    
    return f"""INFORME DE LA MISIÓN:
    {30 * '-'}
    Destino de la misión: {destination}
    {30 * '-'}
    Hora de prelanzamiento: {prelaunch_time} minutos
    Tiempo de vuelo: {flight_time} minutos
    Tiempo total de vuelo = {prelaunch_time + flight_time} minutos
    {30 * '-'}
    Tanque externo: {ext_tank}
    Tanque interno: {int_tank}
    Combustible total: {ext_tank + int_tank}
    {30 * '-'}
    """

print(mission_report(18, 65, "Luna", 250000, 350000))
# Out:
# INFORME DE LA MISIÓN:
#     ------------------------------
#     Destino de la misión: Luna
#     ------------------------------
#     Hora de prelanzamiento: 18 minutos
#     Tiempo de vuelo: 65 minutos
#     Tiempo total de vuelo = 83 minutos
#     ------------------------------
#     Tanque externo: 250000
#     Tanque interno: 350000
#     Combustible total: 600000
#     ------------------------------

# %% [markdown]
# La función es problemática porque no se puede adaptar para minutos adicionales o tanques adicionales de combustible. Hazlo más flexible permitiendo cualquier número de pasos basados en el tiempo y cualquier número de tanques. En lugar de usar `*args` y `**kwargs`, aprovecha el hecho de que puedes usar cualquier nombre que desees. Asegurate que la función sea más legible mediante el uso de nombres de variables que están asociados con las entradas, como `*minutes` y `**fuel_reservoirs`:

# %%
# Escribe tu nueva función de reporte considerando lo anterior
def mission_report(destination, *time_periods, **fuel_tanks):
    
    return f"""INFORME DE LA MISIÓN:
    {30 * '-'}
    Destino de la misión: {destination}
    {30 * '-'}
    Tiempo total de vuelo = {sum(time_periods)} minutos
    {30 * '-'}
    Combustible total: {sum(fuel_tanks.values())} litros
    {30 * '-'}
    """

print(mission_report("Luna", 20, 40, 60, 100, tank1=250000, tank2=350000, tank3=100000))
# Out:
# INFORME DE LA MISIÓN:
#     ------------------------------
#     Destino de la misión: Luna
#     ------------------------------
#     Tiempo total de vuelo = 220 minutos
#     ------------------------------
#     Combustible total: 700000 litros
#     ------------------------------

# %% [markdown]
# Debido a que el combustible que queda en los tanques es específico de cada tanque, actualiza la función para usar el nombre de cada tanque en el informe:

# %%
# Escribe tu nueva función
def mission_report(destination, *time_periods, **fuel_tanks):
    
    report = f"""INFORME DE LA MISIÓN:
    {30 * '-'}
    Destino de la misión: {destination}
    {30 * '-'}
    Tiempo total de vuelo = {sum(time_periods)} minutos
    {30 * '-'}
    Combustible total: {sum(fuel_tanks.values())} litros
    """
    for tank_number, liters in  fuel_tanks.items():
        report += f"{tank_number} le quedan {liters} litros\n"
    {30 * '-'}
    return report        
        
print(mission_report("Luna", 20, 40, 60, 100, tank_1=250000, tank_2=350000, tank_3=100000))
# Out:
# INFORME DE LA MISIÓN:
#     ------------------------------
#     Destino de la misión: Luna
#     ------------------------------
#     Tiempo total de vuelo = 220 minutos
#     ------------------------------
#     Combustible total: 700000 litros
#     tank_1 le quedan 250000 litros
# tank_2 le quedan 350000 litros
# tank_3 le quedan 100000 litros

# %% [markdown]
# ## Soluciones

# %% [markdown]
# ## Ejercicio 1

# %%
# Función para leer 3 tanques de combustible y muestre el promedio

def generate_report(main_tank, external_tank, hydrogen_tank):
    total_average = (main_tank + external_tank + hydrogen_tank) / 3
    return f"""Fuel Report:
    Total Average: {total_average}%
    Main tank: {main_tank}%
    External tank: {external_tank}%
    Hydrogen tank: {hydrogen_tank}% 
    """

# %%
# Llamamos a la función que genera el reporte print(funcion(tanque1, tanque2, tanque3))
print(generate_report(80, 70, 85))
# Out:
# Fuel Report:
#     Total Average: 78.33333333333333%
#     Main tank: 80%
#     External tank: 70%
#     Hydrogen tank: 85%

# %%
# Función promedio 
def average(values):
    total = sum(values)
    number_of_items = len(values)
    return total / number_of_items

# Test the averaging function with a list of integers:
average([80, 85, 81])
# Out:
# 82.0

# %%
# Actualiza la función
def generate_report(main_tank, external_tank, hydrogen_tank):
    return f"""Fuel Report:
    Total Average: {average([main_tank, external_tank, hydrogen_tank])}%
    Main tank: {main_tank}%
    External tank: {external_tank}%
    Hydrogen tank: {hydrogen_tank}% 
    """

# Call the updated function again with different values
print(generate_report(88, 76, 70))
# Out:
# Fuel Report:
#     Total Average: 78.0%
#     Main tank: 88%
#     External tank: 76%
#     Hydrogen tank: 70%

# %% [markdown]
# ### Ejercicio 2:

# %%
# Función con un informe preciso de la misión. Considera hora de prelanzamiento, tiempo de vuelo, destino, tanque externo y tanque interno

def mission_report(pre_launch_time, flight_time, destination, external_tank, main_tank):
    return f"""
    Mission to {destination}
    Total travel time: {pre_launch_time + flight_time} minutes
    Total fuel left: {external_tank + main_tank} gallons
    """

print(mission_report(14, 51, "Moon", 200000, 300000))
# Out:
#     Mission to Moon
#     Total travel time: 65 minutes
#     Total fuel left: 500000 gallons

# %%
# Escribe tu nueva función de reporte considerando lo anterior

def mission_report(destination, *minutes, **fuel_reservoirs):
    return f"""
    Mission to {destination}
    Total travel time: {sum(minutes)} minutes
    Total fuel left: {sum(fuel_reservoirs.values())}
    """

print(mission_report("Moon", 10, 15, 51, main=300000, external=200000))
# Out:
#     Mission to Moon
#     Total travel time: 76 minutes
#     Total fuel left: 500000

# %%
# Escribe tu nueva función

def mission_report(destination, *minutes, **fuel_reservoirs):
    main_report = f"""
    Mission to {destination}
    Total travel time: {sum(minutes)} minutes
    Total fuel left: {sum(fuel_reservoirs.values())}
    """
    for tank_name, gallons in fuel_reservoirs.items():
        main_report += f"{tank_name} tank --> {gallons} gallons left\n"
    return main_report

print(mission_report("Moon", 8, 11, 55, main=300000, external=200000))
# Out:
#     Mission to Moon
#     Total travel time: 74 minutes
#     Total fuel left: 500000
#     main tank --> 300000 gallons left
# external tank --> 200000 gallons left

# %% [markdown]
# ---
#
# Curso Propedútico de Python para Launch X - Innovacción Virtual.
#
# Material desarrollado con base en los contenidos de MSLearn y la metáfora de LaunchX, traducción e implementación por: Fernanda Ochoa - Learning Producer de LaunchX.
#
# Redes:
# * GitHub: [FernandaOchoa](https://github.com/FernandaOchoa)
# * Twitter: [@imonsh](https://twitter.com/imonsh)
# * Instagram: [fherz8a](https://www.instagram.com/fherz8a/)
